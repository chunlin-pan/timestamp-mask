# %%
import timestamp 

filename = 'input.mp4'
time = [2020, 5, 10, 14, 15] #[year, month, day, hour, minute]
start_time = 0
duration = 5
audio = 'off'
output_name = 'output.mp4'
# timestamp.timestamp(filename=filename, time=time, duration=duration, output_name=output_name, start_time=start_time, audio = audio, color='white')

#original video
video = VideoFileClip(filename).subclip(start_time, duration).without_audio()
input_text = TextClip('Input', fontsize=240, color='black').set_duration(5).set_position('center')
video = CompositeVideoClip([video, input_text]).resize(width = 720).speedx(3).write_gif('input_gif.gif')

#text clip
text_list = []
for i in range(duration):
    text_clip = TextClip(timestamp.set_time(time, i)+'\nTimestamp', fontsize=120, color='white').set_duration(1)
    text_list.append(text_clip)
final_text_clip = concatenate_videoclips(text_list).set_position((0.05,0.85), relative=True).speedx(3).write_gif('timestamp_gif.gif',fps = 30)

#video with timestamp
video_with_timestamp = VideoFileClip(output_name)
output_text = TextClip('Output', fontsize=240, color='black').set_duration(5).set_position('center')
CompositeVideoClip([video_with_timestamp, output_text]).resize(width = 720).speedx(3).write_gif('output_gif.gif')
# Out:
#
#
#
#
#
#
# t:  45%|████▍     | 67/150 [1:27:00<03:07,  2.26s/it, now=None]
#
# t:  66%|██████▌   | 197/300 [40:04<02:26,  1.42s/it, now=None]
#
#
# t:  92%|█████████▏| 92/100 [32:56<00:10,  1.37s/it, now=None]
# t:  14%|█▍        | 43/300 [53:53<05:00,  1.17s/it, now=None]
#
#
#
# t:   0%|          | 0/50 [00:00<?, ?it/s, now=None]
#
#
#
# t:   6%|▌         | 3/50 [00:00<00:01, 25.00it/s, now=None]
# MoviePy - Building file timestamp_gif.gif with imageio.
# t:  10%|█         | 5/50 [00:00<00:02, 21.98it/s, now=None]
#
#
#
# t:  14%|█▍        | 7/50 [00:00<00:02, 20.29it/s, now=None]
#
#
#
# t:  18%|█▊        | 9/50 [00:00<00:02, 19.22it/s, now=None]
#
#
#
# t:  22%|██▏       | 11/50 [00:00<00:02, 18.57it/s, now=None]
#
#
#
# t:  26%|██▌       | 13/50 [00:00<00:02, 18.17it/s, now=None]
#
#
#
# t:  30%|███       | 15/50 [00:00<00:01, 17.94it/s, now=None]
#
#
#
# t:  34%|███▍      | 17/50 [00:00<00:01, 17.79it/s, now=None]
#
#
#
# t:  38%|███▊      | 19/50 [00:01<00:01, 17.69it/s, now=None]
#
#
#
# t:  42%|████▏     | 21/50 [00:01<00:01, 17.64it/s, now=None]
#
#
#
# t:  46%|████▌     | 23/50 [00:01<00:01, 17.57it/s, now=None]
#
#
#
# t:  50%|█████     | 25/50 [00:01<00:01, 17.55it/s, now=None]
#
#
#
# t:  54%|█████▍    | 27/50 [00:01<00:01, 17.54it/s, now=None]
#
#
#
# t:  58%|█████▊    | 29/50 [00:01<00:01, 17.51it/s, now=None]
#
#
#
# t:  62%|██████▏   | 31/50 [00:01<00:01, 17.49it/s, now=None]
#
#
#
# t:  66%|██████▌   | 33/50 [00:01<00:00, 17.46it/s, now=None]
#
#
#
# t:  70%|███████   | 35/50 [00:01<00:00, 17.45it/s, now=None]
#
#
#
# t:  74%|███████▍  | 37/50 [00:02<00:00, 17.44it/s, now=None]
#
#
#
# t:  78%|███████▊  | 39/50 [00:02<00:00, 17.46it/s, now=None]
#
#
#
#
#
#
# t:  82%|████████▏ | 41/50 [00:02<00:00, 10.51it/s, now=None]
#
#
#
# t:  86%|████████▌ | 43/50 [00:02<00:00, 11.93it/s, now=None]
#
#
#
# t:  90%|█████████ | 45/50 [00:02<00:00, 13.17it/s, now=None]
#
#
#
# t:  94%|█████████▍| 47/50 [00:02<00:00, 14.21it/s, now=None]
#
#
#
# t:  98%|█████████▊| 49/50 [00:03<00:00, 15.03it/s, now=None]
#
#
#
#
#
#
# t:  45%|████▍     | 67/150 [1:27:04<03:07,  2.26s/it, now=None]A
# t:   0%|          | 0/100 [00:00<?, ?it/s, now=None]
# MoviePy - Building file output_gif.gif with imageio.
# t:   2%|▏         | 2/100 [00:00<00:18,  5.16it/s, now=None]
# t:   3%|▎         | 3/100 [00:00<00:26,  3.71it/s, now=None]
# t:   4%|▍         | 4/100 [00:01<00:30,  3.11it/s, now=None]
# t:   5%|▌         | 5/100 [00:01<00:34,  2.79it/s, now=None]
# t:   6%|▌         | 6/100 [00:02<00:36,  2.60it/s, now=None]
# t:   7%|▋         | 7/100 [00:02<00:37,  2.47it/s, now=None]
# t:   8%|▊         | 8/100 [00:03<00:38,  2.37it/s, now=None]
# t:   9%|▉         | 9/100 [00:03<00:39,  2.32it/s, now=None]
# t:  10%|█         | 10/100 [00:04<00:40,  2.25it/s, now=None]
# t:  11%|█         | 11/100 [00:04<00:39,  2.24it/s, now=None]
# t:  12%|█▏        | 12/100 [00:04<00:39,  2.25it/s, now=None]
# t:  13%|█▎        | 13/100 [00:05<00:38,  2.25it/s, now=None]
# t:  14%|█▍        | 14/100 [00:05<00:38,  2.21it/s, now=None]
# t:  15%|█▌        | 15/100 [00:06<00:39,  2.15it/s, now=None]
# t:  16%|█▌        | 16/100 [00:06<00:40,  2.08it/s, now=None]
# t:  17%|█▋        | 17/100 [00:07<00:39,  2.08it/s, now=None]
# t:  18%|█▊        | 18/100 [00:07<00:39,  2.09it/s, now=None]
# t:  19%|█▉        | 19/100 [00:08<00:38,  2.10it/s, now=None]
# t:  20%|██        | 20/100 [00:08<00:38,  2.07it/s, now=None]
# t:  21%|██        | 21/100 [00:09<00:37,  2.10it/s, now=None]
# t:  22%|██▏       | 22/100 [00:09<00:36,  2.14it/s, now=None]
# t:  23%|██▎       | 23/100 [00:10<00:35,  2.15it/s, now=None]
# t:  24%|██▍       | 24/100 [00:10<00:35,  2.16it/s, now=None]
# t:  25%|██▌       | 25/100 [00:11<00:34,  2.17it/s, now=None]
# t:  26%|██▌       | 26/100 [00:11<00:33,  2.18it/s, now=None]
# t:  27%|██▋       | 27/100 [00:11<00:33,  2.19it/s, now=None]
# t:  28%|██▊       | 28/100 [00:12<00:33,  2.17it/s, now=None]
# t:  29%|██▉       | 29/100 [00:12<00:33,  2.12it/s, now=None]
# t:  30%|███       | 30/100 [00:13<00:32,  2.14it/s, now=None]
# t:  31%|███       | 31/100 [00:13<00:31,  2.17it/s, now=None]
# t:  32%|███▏      | 32/100 [00:14<00:31,  2.18it/s, now=None]
# t:  33%|███▎      | 33/100 [00:14<00:31,  2.16it/s, now=None]
# t:  34%|███▍      | 34/100 [00:15<00:30,  2.15it/s, now=None]
# t:  35%|███▌      | 35/100 [00:15<00:30,  2.16it/s, now=None]
# t:  36%|███▌      | 36/100 [00:16<00:29,  2.19it/s, now=None]
# t:  37%|███▋      | 37/100 [00:16<00:28,  2.19it/s, now=None]
# t:  38%|███▊      | 38/100 [00:17<00:28,  2.20it/s, now=None]
# t:  39%|███▉      | 39/100 [00:17<00:28,  2.17it/s, now=None]
# t:  40%|████      | 40/100 [00:17<00:27,  2.16it/s, now=None]
# t:  41%|████      | 41/100 [00:18<00:27,  2.18it/s, now=None]
# t:  42%|████▏     | 42/100 [00:18<00:26,  2.21it/s, now=None]
# t:  43%|████▎     | 43/100 [00:19<00:25,  2.22it/s, now=None]
# t:  44%|████▍     | 44/100 [00:19<00:25,  2.22it/s, now=None]
# t:  45%|████▌     | 45/100 [00:20<00:24,  2.24it/s, now=None]
# t:  46%|████▌     | 46/100 [00:20<00:24,  2.23it/s, now=None]
# t:  47%|████▋     | 47/100 [00:21<00:23,  2.24it/s, now=None]
# t:  48%|████▊     | 48/100 [00:21<00:23,  2.20it/s, now=None]
# t:  49%|████▉     | 49/100 [00:21<00:22,  2.22it/s, now=None]
# t:  50%|█████     | 50/100 [00:22<00:23,  2.17it/s, now=None]
# t:  51%|█████     | 51/100 [00:22<00:22,  2.20it/s, now=None]
# t:  52%|█████▏    | 52/100 [00:23<00:21,  2.23it/s, now=None]
# t:  53%|█████▎    | 53/100 [00:23<00:21,  2.23it/s, now=None]
# t:  54%|█████▍    | 54/100 [00:24<00:20,  2.25it/s, now=None]
# t:  55%|█████▌    | 55/100 [00:24<00:20,  2.24it/s, now=None]
# t:  56%|█████▌    | 56/100 [00:25<00:19,  2.26it/s, now=None]
# t:  57%|█████▋    | 57/100 [00:25<00:19,  2.25it/s, now=None]
# t:  58%|█████▊    | 58/100 [00:26<00:18,  2.24it/s, now=None]
# t:  59%|█████▉    | 59/100 [00:26<00:18,  2.20it/s, now=None]
# t:  60%|██████    | 60/100 [00:26<00:18,  2.20it/s, now=None]
# t:  61%|██████    | 61/100 [00:27<00:17,  2.21it/s, now=None]
# t:  62%|██████▏   | 62/100 [00:27<00:17,  2.22it/s, now=None]
# t:  63%|██████▎   | 63/100 [00:28<00:16,  2.22it/s, now=None]
# t:  64%|██████▍   | 64/100 [00:28<00:16,  2.21it/s, now=None]
# t:  65%|██████▌   | 65/100 [00:29<00:15,  2.21it/s, now=None]
# t:  66%|██████▌   | 66/100 [00:29<00:15,  2.20it/s, now=None]
# t:  67%|██████▋   | 67/100 [00:30<00:14,  2.21it/s, now=None]
# t:  68%|██████▊   | 68/100 [00:30<00:14,  2.22it/s, now=None]
# t:  69%|██████▉   | 69/100 [00:31<00:13,  2.22it/s, now=None]
# t:  70%|███████   | 70/100 [00:31<00:13,  2.21it/s, now=None]
# t:  71%|███████   | 71/100 [00:31<00:13,  2.17it/s, now=None]
# t:  72%|███████▏  | 72/100 [00:32<00:12,  2.18it/s, now=None]
# t:  73%|███████▎  | 73/100 [00:32<00:12,  2.20it/s, now=None]
# t:  74%|███████▍  | 74/100 [00:33<00:11,  2.19it/s, now=None]
# t:  75%|███████▌  | 75/100 [00:33<00:11,  2.21it/s, now=None]
# t:  76%|███████▌  | 76/100 [00:34<00:10,  2.20it/s, now=None]
# t:  77%|███████▋  | 77/100 [00:34<00:10,  2.21it/s, now=None]
# t:  78%|███████▊  | 78/100 [00:35<00:09,  2.24it/s, now=None]
# t:  79%|███████▉  | 79/100 [00:35<00:09,  2.26it/s, now=None]
# t:  80%|████████  | 80/100 [00:35<00:08,  2.28it/s, now=None]
# t:  81%|████████  | 81/100 [00:36<00:08,  2.26it/s, now=None]
# t:  82%|████████▏ | 82/100 [00:36<00:08,  2.20it/s, now=None]
# t:  83%|████████▎ | 83/100 [00:37<00:07,  2.20it/s, now=None]
# t:  84%|████████▍ | 84/100 [00:37<00:07,  2.19it/s, now=None]
# t:  85%|████████▌ | 85/100 [00:38<00:06,  2.22it/s, now=None]
# t:  86%|████████▌ | 86/100 [00:38<00:06,  2.25it/s, now=None]
# t:  87%|████████▋ | 87/100 [00:39<00:05,  2.26it/s, now=None]
# t:  88%|████████▊ | 88/100 [00:39<00:05,  2.26it/s, now=None]
# t:  89%|████████▉ | 89/100 [00:39<00:04,  2.28it/s, now=None]
# t:  90%|█████████ | 90/100 [00:40<00:04,  2.30it/s, now=None]
# t:  91%|█████████ | 91/100 [00:40<00:03,  2.32it/s, now=None]
# t:  92%|█████████▏| 92/100 [00:41<00:03,  2.34it/s, now=None]
# t:  93%|█████████▎| 93/100 [00:41<00:02,  2.34it/s, now=None]
# t:  94%|█████████▍| 94/100 [00:42<00:02,  2.32it/s, now=None]
# t:  95%|█████████▌| 95/100 [00:42<00:02,  2.29it/s, now=None]
# t:  96%|█████████▌| 96/100 [00:42<00:01,  2.30it/s, now=None]
# t:  97%|█████████▋| 97/100 [00:43<00:01,  2.31it/s, now=None]
# t:  98%|█████████▊| 98/100 [00:43<00:00,  2.32it/s, now=None]
# t:  99%|█████████▉| 99/100 [00:44<00:00,  2.28it/s, now=None]
# t: 100%|██████████| 100/100 [00:44<00:00,  2.31it/s, now=None]
